# %% [markdown]
# This notebook analyzes predictions for only the 15 battleground states in the 2020 election.

# %%
import os
import sys

import numpy as np
import pandas as pd
import seaborn as sb

# %matplotlib inline

# %%
BATTLEGROUNDS = {
    'AZ': 11,
    'FL': 29,
    'GA': 16,
    'IA': 6,
    'ME2': 1, 
    'MI': 16,
    'ME': 2,
    'NE2': 1,
    'NV': 6,
    'NH': 4,
    'NC': 15,
    'OH': 18,
    'PA': 20,
    'TX': 38,
    'WI': 10
}

def get_evs(abbr):
    return BATTLEGROUNDS.get(abbr)

# %%
WINNERS_PATH = os.path.join(DATA_DIR, 'winners.csv')
winners = pd.read_csv(WINNERS_PATH)
evs_called = pd.Series(winners[
    (winners["office"] == "P") &
    (winners["winner"].notnull())
]["state"].unique()).apply(get_evs).sum()

# %%
winners.head()
# Out:
#   office state winner  dem_diff  dem_share  dem_share_2p   candidates
# 0      P    AZ  Biden     0.003      0.494      0.501523  BIDEN|TRUMP
# 1      P    FL  Trump    -0.034      0.479      0.483350  BIDEN|TRUMP
# 2      P    GA  Biden     0.003      0.495      0.501012  BIDEN|TRUMP
# 3      P    IA  Trump    -0.082      0.449      0.458163  BIDEN|TRUMP
# 4      P   ME2  Trump    -0.079      0.447      0.458932  BIDEN|TRUMP

# %%
DATA_DIR = "./597E-assignment1/data"

# %%
source_dfs = []
for fn in os.listdir(os.path.join(DATA_DIR, 'state-level')):
    if 'uva' in fn:
        continue
    print(fn)
    df = pd.read_csv(os.path.join(DATA_DIR, 'state-level', fn))
    source_dfs.append(df)
state_forecasts = pd.concat(source_dfs, axis=0)
state_forecasts.shape
# Out:
# pollyvote.csv
# fivethirtyeight.csv
# northwestern.battleground_only.csv
# economist.csv
# pec.csv
# (18106, 10)

# %%
state_forecasts = state_forecasts[
    (state_forecasts["date"] == "2020-11-03") &
    (state_forecasts["office"] == 'P') &
    (state_forecasts['state'].isin(BATTLEGROUNDS.keys()))]
state_forecasts
# Out:
#            date      model office state party candidate  win_prob  est_diff  \
# 2    2020-11-03  pollyvote      P    NH     D     Biden      0.87       NaN
# 3    2020-11-03  pollyvote      P    NH     R     Trump      0.13       NaN
# 4    2020-11-03  pollyvote      P    ME     D     Biden      0.95       NaN
# 5    2020-11-03  pollyvote      P    ME     R     Trump      0.05       NaN
# 6    2020-11-03  pollyvote      P    NV     D     Biden      0.82       NaN
# ..          ...        ...    ...   ...   ...       ...       ...       ...
# 87   2020-11-03        pec      P    PA     R     Trump      0.11    -0.050
# 96   2020-11-03        pec      P    TX     D     Biden      0.21    -0.027
# 97   2020-11-03        pec      P    TX     R     Trump      0.79     0.027
# 106  2020-11-03        pec      P    WI     D     Biden      0.95     0.085
# 107  2020-11-03        pec      P    WI     R     Trump      0.05    -0.085
#
#      est_share  est_share_2p
# 2          NaN           NaN
# 3          NaN           NaN
# 4          NaN           NaN
# 5          NaN           NaN
# 6          NaN           NaN
# ..         ...           ...
# 87         NaN           NaN
# 96         NaN           NaN
# 97         NaN           NaN
# 106        NaN           NaN
# 107        NaN           NaN
#
# [132 rows x 10 columns]

# %%
state_forecasts['model'].unique()
# Out:
# array(['pollyvote', 'fivethirtyeight-polls-plus', 'northwestern',
#        'economist', 'pec'], dtype=object)

# %%
def get_credits(race):
    max_prob = race["win_prob"].max()
    at_max = race["win_prob"] == max_prob
    favorites = race[at_max]
    credit = (1 / len(favorites)) * favorites["correct"]
    return credit.sum()

def brier_score_race_statelevel(called_forecast):
    uniques = called_forecast[[
        "date", "office", "state", "model"
    ]].apply(lambda x: x.nunique())
    assert((uniques != 1).sum() == 0)
    errors = called_forecast["win_prob"] - called_forecast["correct"]
    errors_squared = (errors).pow(2).sum()
    # If you didn't put odds on the candidate, add 1
    if called_forecast["correct"].sum() == 0:
        errors_squared += 1
    return errors_squared / 2  # divide by 2 bc there are 2 forecasts: Biden and Trump

# %%
def forecast_scores_statelevel(forecasts):
    called = pd.merge(winners, forecasts, on=['office', 'state'], how='left').dropna(
        subset=['winner'])
    called['correct'] = called['winner'] == called['candidate']
    called = called[~called['win_prob'].isnull()]
    
    scores = pd.merge(
        called, forecasts[['date', 'model']].drop_duplicates(),
        how='inner', on=['date', 'model']
    ).groupby([
        'date', 'office', 'state', 'model']).apply(brier_score_race_statelevel)\
            .reset_index()\
            .rename(columns={0: 'brier_score'})
    scores.loc[((scores['office'] == 'P')), 'brier_evs'] = scores.apply(
        lambda x: x['brier_score'] * get_evs(x['state']), axis=1)
    credits = pd.DataFrame({
        "credit": called.groupby([
                "date", "model", "office", "state"
            ]).apply(get_credits)
    }).reset_index()
    scores = pd.DataFrame({
        "pres_brier_flat": scores.groupby("model")["brier_score"].mean(),
        "pres_brier_evs": scores.groupby("model")["brier_evs"].sum() / evs_called,
        "pres_correct": credits[credits["office"] == "P"].groupby("model")["credit"].sum(),
    })
    return scores

# %%
forecast_scores_statelevel(state_forecasts)
# Out:
#                             pres_brier_flat  pres_brier_evs  pres_correct
# model
# economist                          0.143917        0.195667          11.0
# fivethirtyeight-polls-plus         0.133959        0.180526          11.0
# northwestern                       0.153107        0.204028          10.0
# pec                                0.148807        0.174368          12.0
# pollyvote                          0.121027        0.154699          11.0

# %%
forecasts = state_forecasts[state_forecasts['model'] == 'northwestern']
called = pd.merge(winners, forecasts, on=['office', 'state'], how='left').dropna(
        subset=['winner'])
called['correct'] = called['winner'] == called['candidate']
called[~called['win_prob'].isnull()]
# Out:
#    office state winner  dem_diff  dem_share  dem_share_2p   candidates  \
# 0       P    AZ  Biden     0.003      0.494      0.501523  BIDEN|TRUMP
# 1       P    AZ  Biden     0.003      0.494      0.501523  BIDEN|TRUMP
# 2       P    FL  Trump    -0.034      0.479      0.483350  BIDEN|TRUMP
# 3       P    FL  Trump    -0.034      0.479      0.483350  BIDEN|TRUMP
# 4       P    GA  Biden     0.003      0.495      0.501012  BIDEN|TRUMP
# 5       P    GA  Biden     0.003      0.495      0.501012  BIDEN|TRUMP
# 6       P    IA  Trump    -0.082      0.449      0.458163  BIDEN|TRUMP
# 7       P    IA  Trump    -0.082      0.449      0.458163  BIDEN|TRUMP
# 9       P    MI  Biden     0.028      0.506      0.514228  BIDEN|TRUMP
# 10      P    MI  Biden     0.028      0.506      0.514228  BIDEN|TRUMP
# 13      P    NV  Biden     0.024      0.501      0.512270  BIDEN|TRUMP
# 14      P    NV  Biden     0.024      0.501      0.512270  BIDEN|TRUMP
# 15      P    NH  Biden     0.074      0.527      0.537207  BIDEN|TRUMP
# 16      P    NH  Biden     0.074      0.527      0.537207  BIDEN|TRUMP
# 17      P    NC  Trump    -0.013      0.486      0.493401  BIDEN|TRUMP
# 18      P    NC  Trump    -0.013      0.486      0.493401  BIDEN|TRUMP
# 19      P    OH  Trump    -0.080      0.453      0.459432  BIDEN|TRUMP
# 20      P    OH  Trump    -0.080      0.453      0.459432  BIDEN|TRUMP
# 21      P    PA  Biden     0.012      0.500      0.506073  BIDEN|TRUMP
# 22      P    PA  Biden     0.012      0.500      0.506073  BIDEN|TRUMP
# 23      P    TX  Trump    -0.056      0.465      0.471602  BIDEN|TRUMP
# 24      P    TX  Trump    -0.056      0.465      0.471602  BIDEN|TRUMP
# 25      P    WI  Biden     0.006      0.494      0.503055  BIDEN|TRUMP
# 26      P    WI  Biden     0.006      0.494      0.503055  BIDEN|TRUMP
#
#           date         model party candidate  win_prob  est_diff  est_share  \
# 0   2020-11-03  northwestern     D     Biden     0.769       NaN        NaN
# 1   2020-11-03  northwestern     R     Biden     0.231       NaN        NaN
# 2   2020-11-03  northwestern     D     Biden     0.769       NaN        NaN
# 3   2020-11-03  northwestern     R     Biden     0.231       NaN        NaN
# 4   2020-11-03  northwestern     D     Biden     0.785       NaN        NaN
# 5   2020-11-03  northwestern     R     Biden     0.215       NaN        NaN
# 6   2020-11-03  northwestern     R     Trump     0.651       NaN        NaN
# 7   2020-11-03  northwestern     D     Trump     0.349       NaN        NaN
# 9   2020-11-03  northwestern     D     Biden     0.900       NaN        NaN
# 10  2020-11-03  northwestern     R     Biden     0.100       NaN        NaN
# 13  2020-11-03  northwestern     D     Biden     0.593       NaN        NaN
# 14  2020-11-03  northwestern     R     Biden     0.407       NaN        NaN
# 15  2020-11-03  northwestern     D     Biden     0.994       NaN        NaN
# 16  2020-11-03  northwestern     R     Biden     0.006       NaN        NaN
# 17  2020-11-03  northwestern     D     Biden     0.602       NaN        NaN
# 18  2020-11-03  northwestern     R     Biden     0.398       NaN        NaN
# 19  2020-11-03  northwestern     R     Trump     0.563       NaN        NaN
# 20  2020-11-03  northwestern     D     Trump     0.437       NaN        NaN
# 21  2020-11-03  northwestern     D     Biden     0.819       NaN        NaN
# 22  2020-11-03  northwestern     R     Biden     0.181       NaN        NaN
# 23  2020-11-03  northwestern     R     Trump     0.505       NaN        NaN
# 24  2020-11-03  northwestern     D     Trump     0.495       NaN        NaN
# 25  2020-11-03  northwestern     D     Biden     0.867       NaN        NaN
# 26  2020-11-03  northwestern     R     Biden     0.133       NaN        NaN
#
#     est_share_2p  correct
# 0            NaN     True
# 1            NaN     True
# 2            NaN    False
# 3            NaN    False
# 4            NaN     True
# 5            NaN     True
# 6            NaN     True
# 7            NaN     True
# 9            NaN     True
# 10           NaN     True
# 13           NaN     True
# 14           NaN     True
# 15           NaN     True
# 16           NaN     True
# 17           NaN    False
# 18           NaN    False
# 19           NaN     True
# 20           NaN     True
# 21           NaN     True
# 22           NaN     True
# 23           NaN     True
# 24           NaN     True
# 25           NaN     True
# 26           NaN     True

# %%
forecasts = state_forecasts[state_forecasts['model'] == 'pec']
forecasts.shape
# Out:
# (30, 10)

# %%
forecasts
# Out:
#            date model office state party candidate  win_prob  est_diff  \
# 6    2020-11-03   pec      P    AZ     D     BIDEN      0.80    0.0300
# 7    2020-11-03   pec      P    AZ     R     TRUMP      0.20   -0.0300
# 18   2020-11-03   pec      P    FL     D     BIDEN      0.81    0.0300
# 19   2020-11-03   pec      P    FL     R     TRUMP      0.19   -0.0300
# 20   2020-11-03   pec      P    GA     D     BIDEN      0.64    0.0150
# 21   2020-11-03   pec      P    GA     R     TRUMP      0.36   -0.0150
# 24   2020-11-03   pec      P    IA     D     BIDEN      0.38   -0.0100
# 25   2020-11-03   pec      P    IA     R     TRUMP      0.62    0.0100
# 42   2020-11-03   pec      P    ME     D     BIDEN      1.00    0.1300
# 43   2020-11-03   pec      P    ME     R     TRUMP      0.00   -0.1300
# 46   2020-11-03   pec      P   ME2     D     BIDEN      0.78       NaN
# 47   2020-11-03   pec      P   ME2     R     TRUMP      0.22       NaN
# 48   2020-11-03   pec      P    MI     D     BIDEN      0.95    0.0750
# 49   2020-11-03   pec      P    MI     R     TRUMP      0.05   -0.0750
# 58   2020-11-03   pec      P    NC     D     BIDEN      0.72    0.0200
# 59   2020-11-03   pec      P    NC     R     TRUMP      0.28   -0.0200
# 66   2020-11-03   pec      P   NE2     D     BIDEN      0.87       NaN
# 67   2020-11-03   pec      P   NE2     R     TRUMP      0.13       NaN
# 70   2020-11-03   pec      P    NH     D     BIDEN      0.93    0.0800
# 71   2020-11-03   pec      P    NH     R     TRUMP      0.07   -0.0800
# 76   2020-11-03   pec      P    NV     D     BIDEN      0.91    0.0600
# 77   2020-11-03   pec      P    NV     R     TRUMP      0.09   -0.0600
# 80   2020-11-03   pec      P    OH     D     BIDEN      0.21   -0.0275
# 81   2020-11-03   pec      P    OH     R     TRUMP      0.79    0.0275
# 86   2020-11-03   pec      P    PA     D     BIDEN      0.89    0.0500
# 87   2020-11-03   pec      P    PA     R     TRUMP      0.11   -0.0500
# 96   2020-11-03   pec      P    TX     D     BIDEN      0.21   -0.0270
# 97   2020-11-03   pec      P    TX     R     TRUMP      0.79    0.0270
# 106  2020-11-03   pec      P    WI     D     BIDEN      0.95    0.0850
# 107  2020-11-03   pec      P    WI     R     TRUMP      0.05   -0.0850
#
#      est_share  est_share_2p
# 6          NaN           NaN
# 7          NaN           NaN
# 18         NaN           NaN
# 19         NaN           NaN
# 20         NaN           NaN
# 21         NaN           NaN
# 24         NaN           NaN
# 25         NaN           NaN
# 42         NaN           NaN
# 43         NaN           NaN
# 46         NaN           NaN
# 47         NaN           NaN
# 48         NaN           NaN
# 49         NaN           NaN
# 58         NaN           NaN
# 59         NaN           NaN
# 66         NaN           NaN
# 67         NaN           NaN
# 70         NaN           NaN
# 71         NaN           NaN
# 76         NaN           NaN
# 77         NaN           NaN
# 80         NaN           NaN
# 81         NaN           NaN
# 86         NaN           NaN
# 87         NaN           NaN
# 96         NaN           NaN
# 97         NaN           NaN
# 106        NaN           NaN
# 107        NaN           NaN
